# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
county_list = [
    'Alameda', 
    'Amador',
    'Butte',
    'Calaveras',
    'Colusa',
    'Contra Costa',
    'El Dorado',
    'Fresno',
    'Glenn',
    'Humboldt',
    'Kern',
    'Kings',
    'Lake',
    'Lassen',
    'Los Angeles',
    'Madera',
    'Marin',
    'Mariposa',
    'Mendocino',
    'Merced',
    'Monterey',
    'Napa',
    'Nevada',
    'Orange',
    'Placer',
    'Riverside',
    'Sacramento',
    'San Benito',
    'San Bernardino',
    'San Diego',
    'San Joaquin',
    'San Luis Obispo',
    'San Mateo',
    'Santa Barbara',
    'Santa Clara',
    'Santa Cruz',
    'Shasta',
    'Siskiyou',
    'Solano',
    'Sonoma',
    'Stanislaus',
    'Sutter',
    'Tehama',
    'Trinity',
    'Tulare',
    'Tuolumne',
    'Ventura',
    'Yolo',
    'Yuba'] # 2024 county list

# %%
district_dict = {
    1: ['Mendocino'],
    2: ['Lake'],
    3: ['Sonoma', 'Marin'],
    4: ['Napa'],
    5: ['Solano'],
    6: ['Alameda', 'Contra Costa', 'Santa Clara', 'San Francisco', 'San Mateo', 'Santa Cruz Counties'],
    7: ['Monterey', 'San Benito'],
    8: ['San Luis Obispo', 'Santa Barbara', 'Ventura'],
    9: ['Yolo', 'Del Norte', 'Siskiyou', 'Modoc', 'Humboldt', 'Trinity', 'Shasta', 'Lassen', 'Tehama', 'Ventura',
       'Plumas', 'Glenn', 'Butte', 'Colusa', 'Sutter', 'Yub', 'Los Angeles', 'Sierra'],
    10: ['Nevada', 'Placer', 'El Dorado', 'Amador', 'Calaveras', 'Tuolumne', 'Mariposa'],
    11: ['San Joaquin',  'Sacramento'],
    12: ['San Joaquin County', 'Stanislaus', 'Merced'],
    13: ['Madera', 'Fresno', 'Alpine', 'Mono', 'Inyo','Kings','Tulare'],
    14: ['Kings', 'Tulare', 'Kern'],
    15: ['Los Angeles', 'San Bernardino'],
    16: ['Orange', 'Riverside', 'San Diego', 'Imperial'],
    17: ['Yolo', 'Sacramento']
    
}

# %%
variety_df_2024 = pd.read_excel('C:/Users/lilli/Documents/NSS/Capstone/usda/2024_wine.xlsx', sheet_name = 4)
variety_df_2024['Year'] = 2024
variety_df_2024 = variety_df_2024.dropna(subset=variety_df_2024.columns[0]).drop(columns=[variety_df_2024.columns[1],
                                                                        variety_df_2024.columns[2],
                                                                        variety_df_2024.columns[3],
                                                                        variety_df_2024.columns[4],
                                                                        variety_df_2024.columns[5],
                                                                        variety_df_2024.columns[6], 
                                                                        variety_df_2024.columns[7],
                                                                        variety_df_2024.columns[8], 
                                                                        variety_df_2024.columns[9],
                                                                        variety_df_2024.columns[13]]).rename(columns={
                                                                                                    variety_df_2024.columns[0]:'Variety/County',
                                                                                                    variety_df_2024.columns[10]:'Bearing',
                                                                                                    variety_df_2024.columns[11]:'Non-Bearing',
                                                                                                    variety_df_2024.columns[12]:'Total'})

# %%
def load_wine_dataframes(file_path, sheet_name, year):
    df = pd.read_excel(file_path, sheet_name)
    df['year'] = year
    df = df.rename(columns={df.columns[0]:'variety/county',
                            df.columns[10]:'bearing_acre',
                            df.columns[11]:'non-bearing_acre',
                            df.columns[12]:'total_acre',})
    df = df.drop(columns=[df.columns[1],
                          df.columns[2],
                          df.columns[3],
                          df.columns[4],
                          df.columns[5],
                          df.columns[6],
                          df.columns[7],
                          df.columns[8],
                          df.columns[9],
                          df.columns[13]])
    
    return df

# %%
white_2024 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2024_wine.xlsx', 3, 2024)
white_2023 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2023_wine.xlsx', 3, 2023)
white_2022 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2022_wine.xlsx', 3, 2022)
white_2021 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2021_wine.xlsx', 3, 2021)
white_2020 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2020_wine.xlsx', 3, 2020)
white_2019 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2019_wine.xlsx', 3, 2019)
white_2018 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2018_wine.xlsx', 3, 2018)
white_2017 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2017_wine.xlsx', 3, 2017)
white_2016 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2016_wine.xlsx', 3, 2016)
white_2015 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2015_wine.xlsx', 3, 2015)
white_2014 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2014_wine.xlsx', 3, 2014)
white_2013 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2013_wine.xlsx', 3, 2013)
white_2012 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2012_wine.xlsx', 3, 2012)
white_2011 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2011_wine.xlsx', 3, 2011)
white_2010 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2010_wine.xlsx', 3, 2010)
white_2009 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2009_wine.xlsx', 3, 2009)
white_2008 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2008_wine.xlsx', 3, 2008)
white_2007 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2007_wine.xlsx', 3, 2007)
white_2006 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2006_wine.xlsx', 3, 2006)
white_2005 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2005_wine.xlsx', 3, 2005)
white_2004 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2004_wine.xlsx', 3, 2004)
white_2003 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2003_wine.xlsx', 3, 2003)
white_2002 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2002_wine.xlsx', 3, 2002)
white_2001 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2001_wine.xlsx', 3, 2001)
white_2000 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2000_wine.xlsx', 3, 2000)

# %%
red_2024 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2024_wine.xlsx', 4, 2024)
red_2023 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2023_wine.xlsx', 4, 2023)
red_2022 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2022_wine.xlsx', 4, 2022)
red_2021 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2021_wine.xlsx', 4, 2021)
red_2020 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2020_wine.xlsx', 4, 2020)
red_2019 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2019_wine.xlsx', 4, 2019)
red_2018 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2018_wine.xlsx', 4, 2018)
red_2017 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2017_wine.xlsx', 4, 2017)
red_2016 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2016_wine.xlsx', 4, 2016)
red_2015 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2015_wine.xlsx', 4, 2015)
red_2014 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2014_wine.xlsx', 4, 2014)
red_2013 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2013_wine.xlsx', 4, 2013)
red_2012 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2012_wine.xlsx', 4, 2012)
red_2011 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2011_wine.xlsx', 4, 2011)
red_2010 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2010_wine.xlsx', 4, 2010)
red_2009 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2009_wine.xlsx', 4, 2009)
red_2008 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2008_wine.xlsx', 4, 2008)
red_2007 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2007_wine.xlsx', 4, 2007)
red_2006 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2006_wine.xlsx', 4, 2006)
red_2005 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2005_wine.xlsx', 4, 2005)
red_2004 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2004_wine.xlsx', 4, 2004)
red_2003 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2003_wine.xlsx', 4, 2003)
red_2002 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2002_wine.xlsx', 4, 2002)
red_2001 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2001_wine.xlsx', 4, 2001)
red_2000 = load_wine_dataframes('C:/Users/lilli/Documents/NSS/Capstone/usda/2000_wine.xlsx', 4, 2000)

# %%
red_concat = pd.concat([
    red_2024,
    red_2023,
    red_2022,
    red_2021,
    red_2020,
    red_2019,
    red_2018,
    red_2017,
    red_2016,
    red_2015,
    red_2014,
    red_2013,
    red_2012,
    red_2011,
    red_2010,
    red_2009,
    red_2008,
    red_2007,
    red_2006,
    red_2005,
    red_2004,
    red_2003,
    red_2002,
    red_2001,
    red_2000], axis=0, ignore_index=True)

# %%
#set(red_concat['variety/county'])

# %%
red_variety = [
    'AGLIANICO',
    'ALICANTE BOUSCHET',
    'BARBERA',
    'BOUSCHET',
    'CABERNET FRANC',
    'CABERNET SAUVIGNON',
    'CARIGNANE',
    'CARMENERE',
    'CARMINE',
    'CARNELIAN',
    'CENTURIAN',
    'CHARBONO',
    'CINSAUT',
    'COUNOISE',
    'DOLCETTO',
    'DORNFELDER',
    'DURIF',
    'FREISA',
    'GAMAY',
    'GAMAY BEAUJOLAIS',
    'GRACIANO',
    'GRENACHE',
    'GRIGNOLINO',
    'LAGREIN',
    'LAMBRUSCO',
    'MALBEC',
    'MATARO',
    'MERLOT',
    'MEUNIER',
    'MISSION',
    'MONTEPULCIANO',
    'MOURVEDRE',
    'MUSCAT HAMBURG',
    'NEBBIOLO',
    "NERO D'AVOLA",
    'OTHER RED WINE',
    'PETIT VERDOT',
    'PETITE SIRAH ',
    'PINOT NOIR',
    'PINOTAGE',
    'PRIMITIVO',
    'ROYALTY',
    'RUBIRED',
    'RUBY CABERNET',
    'SALVADOR',
    'SANGIOVESE',
    'SANGIOVETO',
    'SOUZAO',
    'SYRAH',
    'TANNAT',
    'TEMPRANILLO',
    'TEROLDEGO',
    'TOURIGA FRANCESCA',
    'TOURIGA NACIONAL',
    'VALDIGUIE',
    'ZINFANDEL'   
]

# %%
white_concat = pd.concat([
    white_2024,
    white_2023,
    white_2022,
    white_2021,
    white_2020,
    white_2019,
    white_2018,
    white_2017,
    white_2016,
    white_2015,
    white_2014,
    white_2013,
    white_2012,
    white_2011,
    white_2010,
    white_2009,
    white_2008,
    white_2007,
    white_2006,
    white_2005,
    white_2004,
    white_2003,
    white_2002,
    white_2001,
    white_2000], axis=0, ignore_index=True)

# %%
#set(white_concat['variety/county'])

# %%
white_variety = [
    'ALBARINO',
    'ARNEIS',
    'BURGER',
    'CATARRATTO',
    'CHARDONNAY',
    'CHENIN BLANC',
    'EMERALD RIESLING',
    'FOLLE BLANCHE',
    'FRENCH COLOMBARD',
    'GEWURZTRAMINER',
    'GRAY RIESLING',
    'GRENACHE BLANC',
    'GRUNER VELTLINER',
    'HUNGARIAN MILLENIUM',
    'MALVASIA BIANCA',
    'MARSANNE',
    'MOSCATO GAILLO',
    'MUSCAT',
    'MUSCAT BLANC',
    'MUSCAT OF ALEXANDRIA',
    'MUSCAT ORANGE',
    'OTHER WHITE WINE',
    'PALOMINO',
    'PICPOUL BLANC',
    'PINOT BLANC',
    'PINOT GRIS',
    'ROUSSANNE',
    'SAUVIGNON BLANC',
    'SAUVIGNON MUSQUE',
    'SAUVIGNON VERT',
    'SEMILLON',
    'ST EMILION',
    'SYMPHONY',
    'TOCAI FRIULANO',
    'TRIPLETT BLANC',
    'VERDELHO',
    'VERMENTINO',
    'VIOGNIER',
    'WHITE RIESLING']

# %%
# next steps: 1. make dfs for all years and concat, 2. drop + rename columns 3. normalize variety/county 4. make county column (ideal)

# %%
final_concat = pd.concat([red_concat, white_concat], axis=0, ignore_index=True)

# %%
labor = pd.read_csv('C:/Users/lilli/Documents/NSS/Capstone/labor_data.csv').drop(columns=['Program', 'Period', 'Week Ending', 
                                                                                          'Geo Level', 'State','State ANSI', 'Ag District',
                                                                                          'Ag District Code', 'County','County ANSI', 'Zip Code',
                                                                                          'Region', 'watershed_code', 'Watershed','Commodity',
                                                                                          'Data Item', 'Domain', 'Domain Category','CV (%)']).rename(
                                                                                           columns={'Year':'year', 'Value':'avg_labor_hired'})

# %%
wine_labor = pd.merge(final_concat, labor, on='year', how='inner')

# %%
wine_labor
# Out:
#            variety/county bearing_acre                 non-bearing_acre  \
# 0      Variety and County         2024                              NaN
# 1                     NaN      Bearing  Non-                  Bearing 2
# 2                     NaN          NaN                              NaN
# 3                     NaN          NaN                              NaN
# 4               AGLIANICO          NaN                              NaN
# ...                   ...          ...                              ...
# 42707             Ventura            3                                0
# 42708                Yolo         4382                             1003
# 42709                Yuba          111                                0
# 42710                 NaN          NaN                              NaN
# 42711         State Total       182223                            20236
#
#       total_acre  year avg_labor_hired
# 0            NaN  2024         144,000
# ...

# %%
data = wine_labor['variety/county']

data = data.str.strip()
data = data.str.replace(r'\W+[*]', '', regex=True)
#r'' = raw string, \W = not a word, + = one or more, [*] = select * within string, literal *
data = data.str.replace('*', '')
data = data.str.replace( r"\W[(]Cont'd[.]?[)]", '', regex=True )
#r"" = raw string, \W = not a word (a blank space), [(] = select ( within string, Cont'd = "Cont'd", [.] = select literal . ,
    #? = zero or one (characters)
data = data.str.replace( r'GAMAY.*', 'GAMAY', regex=True)
#r'' = raw string, . = any character (except line break), * = zero or more times the character appears
data = data.str.replace( r'.*MUSCAT OF.*', 'OF ALEXANDRIA', regex=True)
#r'' = raw string, . = any character (except line break), * = zero or more times the character appears, MUSCAT OF = 'MUSCAT OF',
    #. = any character (except line break), * = zero or more times the character appears
    #replacing any instances of MUSCAT OF or MUSCAT MUSCAT OF with OF ALEXANDRIA, to transform from there (next line)
data = data.str.replace('OF ALEXANDRIA', 'MUSCAT OF ALEXANDRIA')
data = data.str.replace('ALEXANDRIA', 'MUSCAT OF ALEXANDRIA')
data = data.str.replace(r'ST[.]\W*', 'ST ', regex=True)
#r'' = raw string, ST = 'ST', [.] = select literal . , \W = not a word, * = zero or more times the character appears
data = data.str.replace('SYRAH NOIR', 'SYRAH')
data = data.str.replace( r'San Luis Obispo*', 'San Luis Obispo', regex=True)
#r'' = raw string, San Luis Obispo = 'San Luis Obispo', * = zero or more times the character appears
data = data.str.replace('Siskyou', 'Siskiyou')
data = data.str.replace('Tuolomne', 'Tuolumne')
data= data.str.replace('CABERNET CABERNET SAUVIGNON', 'CABERNET SAUVIGNON')

# %%
#set(data)
# use to compare regex changes to set (unique values in column)

# %%
wine_labor['variety/county'] = data
# set cleaned data to wine_labor['variety/county']

# %%
current_value = '' # placeholder
variety_list = []

for value in wine_labor['variety/county']:
    if str(value).isupper():
        current_value = value # stay on upper value (variety are in upper)
    variety_list.append(current_value)

# %%
wine_labor['variety'] = variety_list

# %%
#wine_labor_clean = wine_labor.dropna().rename(columns={'variety/county':'county'})
# drop irrelevant rows and rename split variety/county columns
#wine_final = wine_labor_clean[wine_labor_clean['county'].isin(county_list)].reset_index()
# maintain correct county list, dropping any aggregates ('State Total')

# %%
wine_labor_clean = wine_labor.rename(columns={'variety/county':'county'})
# rename split variety/county columns
wine_final = wine_labor_clean[wine_labor_clean['county'].isin(county_list)].reset_index()
# maintain correct county list, dropping any aggregates ('State Total')

# %%
set(wine_final['variety'])
# Out:
# {'AGLIANICO',
#  'ALBARINO',
#  'ALICANTE BOUSCHET',
#  'ARNEIS',
#  'BARBERA',
#  'BOUSCHET',
#  'BURGER',
#  'CABERNET FRANC',
#  'CABERNET SAUVIGNON',
#  'CARIGNANE',
#  'CARMENERE',
#  'CARMINE',
#  'CARNELIAN',
#  'CATARRATTO',
#  'CENTURIAN',
#  'CHARBONO',
#  'CHARDONNAY',
#  'CHENIN BLANC',
#  'CINSAUT',
#  'COUNOISE',
#  'DOLCETTO',
#  'DORNFELDER',
#  'DURIF',
#  'EMERALD RIESLING',
#  'FOLLE BLANCHE',
#  'FREISA',
#  'FRENCH COLOMBARD',
#  'GAMAY',
#  'GEWURZTRAMINER',
#  'GRACIANO',
#  'GRAY RIESLING',
#  'GRENACHE',
#  'GRENACHE BLANC',
#  'GRIGNOLINO',
#  'GRUNER VELTLINER',
#  'HUNGARIAN MILLENIUM',
#  'LAGREIN',
#  'LAMBRUSCO',
#  'MALBEC',
#  'MALVASIA BIANCA',
#  'MARSANNE',
#  'MATARO',
#  'MERLOT',
#  'MEUNIER',
#  'MISSION',
#  'MONTEPULCIANO',
#  'MOSCATO GAILLO',
#  'MOURVEDRE',
#  'MUSCAT BLANC',
#  'MUSCAT HAMBURG',
#  'MUSCAT OF ALEXANDRIA',
#  'MUSCAT OF MUSCAT OF ALEXANDRIA',
#  'MUSCAT ORANGE',
#  'NEBBIOLO',
#  "NERO D'AVOLA",
#  'OTHER RED WINE',
# ...

# %%
# over all years, how many unique varieties are found in each county
wine_final.groupby('county')['variety'].nunique()
# Out:
# county
# Alameda            45
# Amador             57
# Butte              30
# Calaveras          53
# Colusa             17
# Contra Costa       43
# El Dorado          69
# Fresno             61
# Glenn              17
# Humboldt           22
# Kern               46
# Kings              31
# Lake               51
# Lassen              6
# Los Angeles        25
# Madera             67
# Marin              17
# Mariposa           20
# Mendocino          68
# Merced             41
# Monterey           64
# Napa               79
# Nevada             41
# Orange              3
# Placer             36
# Riverside          70
# Sacramento         54
# San Benito         48
# San Bernardino     30
# San Diego          55
# San Joaquin        83
# San Luis Obispo    76
# San Mateo          16
# Santa Barbara      65
# Santa Clara        52
# Santa Cruz         28
# Shasta             27
# Siskiyou           14
# Solano             52
# Sonoma             86
# Stanislaus         45
# ...

# %%
# by year, unique variety count by county
wine_final.groupby(['year', 'county'])['variety'].nunique()
# Out:
# year  county
# 2000  Alameda      28
#       Amador       31
#       Butte         6
#       Calaveras    20
#       Colusa        7
#                    ..
# 2024  Tulare       28
#       Tuolumne     16
#       Ventura      19
#       Yolo         44
#       Yuba         13
# Name: variety, Length: 1196, dtype: int64

# %%
wine_final.to_csv(r'C:/Users/lilli/Documents/NSS/Python/wine_final.csv')
# send directly to correct location to overview in PowerBI

# %%
# varieties increasing/decreasing over time
distribution_grouped = wine_final.groupby(['year', 'variety'])['bearing_acre'].sum().reset_index()
distribution_grouped
# Out:
#       year             variety bearing_acre
# 0     2000   ALICANTE BOUSCHET         1403
# 1     2000             BARBERA        10566
# 2     2000              BURGER         1837
# 3     2000      CABERNET FRANC         2382
# 4     2000  CABERNET SAUVIGNON        48286
# ...    ...                 ...          ...
# 1796  2024            VERDELHO          149
# 1797  2024          VERMENTINO          140
# 1798  2024            VIOGNIER         2422
# 1799  2024      WHITE RIESLING         2638
# 1800  2024           ZINFANDEL        35616
#
# [1801 rows x 3 columns]

# %%
# 1. What are the top 10 varieties, varying across all years (2003-2024*), in terms of bearing acres? *2005-2024. See NOTE for 2004
top_varieties_list
# there are 12 in the list due to varying top 10s per year
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[81], line 2
#       1 # 1. What are the top 10 varieties, varying across all years (2003-2024*), in terms of bearing acres? *2005-2024. See NOTE for 2004
# ----> 2 top_varieties_list
#
# NameError: name 'top_varieties_list' is not defined

# %%
variety_2024 = distribution_grouped[distribution_grouped['year'] == 2024].sort_values('bearing_acre', ascending=False).head(12)['variety'].to_list()
filtered_years = distribution_grouped[(distribution_grouped['year'] >= 2003) & (distribution_grouped['year'] <= 2024)]
# ideas for code, manually looking at years to decide range
# NOTE: head(12) is used to factor for TOTAL RED/TOTAL WHITE, aggregate rows from the dataframe (always top 2)

# %%
# loop through relevant years, creating a dictionary with years and their top 12 varieties
top_varieties = {}

for year in range(2003, 2025):
    top_per_year = distribution_grouped[distribution_grouped['year'] == year].sort_values('bearing_acre', ascending=False).head(12)['variety'].to_list()

    top_varieties[year] = top_per_year

# %%
# loop through dictionary, extracting a list of varieties

unique_varieties = []

for variety in top_varieties.values(): # values() is interacting with the values, not keys (years)
    unique_varieties.append(variety)

# list of lists - needs to be flattened https://stackoverflow.com/questions/952914/how-do-i-make-a-flat-list-out-of-a-list-of-lists

# %%
# for sake of time, roughly simplified list of lists by pulling just 2024 and 2005 and making them into a set
variety_2024 = distribution_grouped[distribution_grouped['year'] == 2024].sort_values('bearing_acre', ascending=False).head(12)['variety'].to_list()
variety_2003 = distribution_grouped[distribution_grouped['year'] == 2005].sort_values('bearing_acre', ascending=False).head(12)['variety'].to_list()
top_varieties_list = list(set(variety_2003 + variety_2024)) 
top_varieties_list.remove('OTHER WHITE WINE')
top_varieties_list.remove('OTHER RED WINE')
top_varieties_list.remove('TOTAL WHITE WINE')
top_varieties_list.remove('TOTAL RED WINE')

# %%
# 2. What's the total bearing acreage per year, for each of the Top 12?

# Narrow wine_final to only have top_varieties_list, in the years 2003-2024
# Make chart that shows acreage per year

# %%
filtered_wine = wine_final[
    (wine_final['year'] >= 2003) &
    (wine_final['year'] <= 2024) &
    (wine_final['variety'].isin(top_varieties_list))]

filtered_wine.groupby('year')['bearing_acre'].sum().reset_index()

# NOTE: 2004 was unusual, decided to invesigate
# Out:
#     year bearing_acre
# 0   2003       370066
# 1   2004       304475
# 2   2005       381428
# 3   2006       384433
# 4   2007       380161
# 5   2008       378510
# 6   2009       382231
# 7   2010       389828
# 8   2011       393746
# 9   2012       391852
# 10  2013       399775
# 11  2014       395368
# 12  2015       393241
# 13  2016       390668
# 14  2017       391457
# 15  2018       392046
# 16  2019       391183
# 17  2020       386258
# 18  2021       384976
# 19  2022       383339
# 20  2023       380803
# 21  2024       374777

# %%
wine_labor[wine_labor['variety'] == 'SAUVIGNON']

# Looks like I accidentally dropped Cabernet Sauvignon from the list for 2004. 
# It's in wine_labor under SAUVIGNON. Since it's such a major part of the dataset, I'll work with 2005-2024 instead since two years is not a major loss
# Out:
#         variety/county bearing_acre non-bearing_acre total_acre  year  \
# 21687        SAUVIGNON          NaN              NaN        NaN  2004
# 21688          Alameda          319               17        335  2004
# 21689           Amador          130                0        130  2004
# 21690            Butte           53                0         54  2004
# 21691        Calaveras          123                0        123  2004
# 21692           Colusa           80                0         80  2004
# 21693     Contra Costa           22                0         22  2004
# 21694        El Dorado          243                8        251  2004
# 21695           Fresno         1517                0       1517  2004
# 21696         Humboldt            2                1          3  2004
# 21697             Kern          979                0        979  2004
# 21698            Kings            0                0          0  2004
# ...

# %%
# updated year range
filtered_updated = wine_final[
    (wine_final['year'] >= 2005) &
    (wine_final['year'] <= 2024) &
    (wine_final['variety'].isin(top_varieties_list))]

total_acreage = filtered_updated.groupby('year')['bearing_acre'].sum().reset_index()

plt.figure(figsize=(10,6))
sns.lineplot(data=total_acreage, x='year', y='bearing_acre', marker='o')

plt.title('Total Bearing Acreage per Year (Top Varieties, 2005–2024)')
plt.xlabel('Year')
plt.ylabel('Total Bearing Acres')

plt.tight_layout() # auto-adjust padding for cleaner look #https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.tight_layout.html
plt.xticks(range(2005, 2025, 1)) # https://stackoverflow.com/questions/56713197/how-to-change-the-xticks-to-a-specific-range
plt.show()

# %%
# 3. How has acreage per year for varieties in the Top 12 changed over time?
# make charts for each variety, showing how each top variety has changed over 2005-2024

varieties_grouped = filtered_updated.groupby(['year', 'variety'])['bearing_acre'].sum().reset_index()
# the sum of bearing_acre by year, by variety

# %%
# looking to make a plot of each Top Variety, for each year

grouped_cab = varieties_grouped[varieties_grouped['variety'] == 'CABERNET SAUVIGNON']


plt.figure(figsize=(10,6))
sns.lineplot(data=grouped_cab, x='year', y='bearing_acre', marker='o')

plt.title('Cabernet Sauvignon, Bearing Acreage per Year (2005–2024)')
plt.xlabel('Year')
plt.ylabel('Total Bearing Acres')

plt.tight_layout()
plt.xticks(range(2005, 2025, 1))
plt.show()

# %%
grouped_chard = varieties_grouped[varieties_grouped['variety'] == 'CHARDONNAY']


plt.figure(figsize=(10,6))
sns.lineplot(data=grouped_chard, x='year', y='bearing_acre', marker='o')

plt.title('Chardonnay, Bearing Acreage per Year (2005–2024)')
plt.xlabel('Year')
plt.ylabel('Total Bearing Acres')

plt.tight_layout()
plt.xticks(range(2005, 2025, 1))
plt.show()

# %%
grouped_syrah = varieties_grouped[varieties_grouped['variety'] == 'SYRAH']


plt.figure(figsize=(10,6))
sns.lineplot(data=grouped_syrah, x='year', y='bearing_acre', marker='o')

plt.title('Syrah, Bearing Acreage per Year (2005–2024)')
plt.xlabel('Year')
plt.ylabel('Total Bearing Acres')

plt.tight_layout()
plt.xticks(range(2005, 2025, 1))
plt.show()

# %%
grouped_gris = varieties_grouped[varieties_grouped['variety'] == 'PINOT GRIS']


plt.figure(figsize=(10,6))
sns.lineplot(data=grouped_gris, x='year', y='bearing_acre', marker='o')

plt.title('Pinot Gris, Bearing Acreage per Year (2005–2024)')
plt.xlabel('Year')
plt.ylabel('Total Bearing Acres')

plt.tight_layout()
plt.xticks(range(2005, 2025, 1))
plt.show()

# %%
grouped_merlot = varieties_grouped[varieties_grouped['variety'] == 'MERLOT']


plt.figure(figsize=(10,6))
sns.lineplot(data=grouped_merlot, x='year', y='bearing_acre', marker='o')

plt.title('Merlot, Bearing Acreage per Year (2005–2024)')
plt.xlabel('Year')
plt.ylabel('Total Bearing Acres')

plt.tight_layout()
plt.xticks(range(2005, 2025, 1))
plt.show()

# %%
grouped_chenin = varieties_grouped[varieties_grouped['variety'] == 'CHENIN BLANC']


plt.figure(figsize=(10,6))
sns.lineplot(data=grouped_chenin, x='year', y='bearing_acre', marker='o')

plt.title('Chenin Blanc, Bearing Acreage per Year (2005–2024)')
plt.xlabel('Year')
plt.ylabel('Total Bearing Acres')

plt.tight_layout()
plt.xticks(range(2005, 2025, 1))
plt.show()

# %%
grouped_colombard = varieties_grouped[varieties_grouped['variety'] == 'FRENCH COLOMBARD']


plt.figure(figsize=(10,6))
sns.lineplot(data=grouped_colombard, x='year', y='bearing_acre', marker='o')

plt.title('French Colombard, Bearing Acreage per Year (2005–2024)')
plt.xlabel('Year')
plt.ylabel('Total Bearing Acres')

plt.tight_layout()
plt.xticks(range(2005, 2025, 1))
plt.show()

# %%
grouped_zin = varieties_grouped[varieties_grouped['variety'] == 'ZINFANDEL']


plt.figure(figsize=(10,6))
sns.lineplot(data=grouped_zin, x='year', y='bearing_acre', marker='o')

plt.title('Zinfandel, Bearing Acreage per Year (2005–2024)')
plt.xlabel('Year')
plt.ylabel('Total Bearing Acres')

plt.tight_layout()
plt.xticks(range(2005, 2025, 1))
plt.show()

# %%
grouped_noir = varieties_grouped[varieties_grouped['variety'] == 'PINOT NOIR']


plt.figure(figsize=(10,6))
sns.lineplot(data=grouped_noir, x='year', y='bearing_acre', marker='o')

plt.title('Pinot Noir, Bearing Acreage per Year (2005–2024)')
plt.xlabel('Year')
plt.ylabel('Total Bearing Acres')

plt.tight_layout()
plt.xticks(range(2005, 2025, 1))
plt.show()

# %%
grouped_sauvblanc = varieties_grouped[varieties_grouped['variety'] == 'SAUVIGNON BLANC']


plt.figure(figsize=(10,6))
sns.lineplot(data=grouped_sauvblanc, x='year', y='bearing_acre', marker='o')

plt.title('Sauvignon Blanc, Bearing Acreage per Year (2005–2024)')
plt.xlabel('Year')
plt.ylabel('Total Bearing Acres')

plt.tight_layout()
plt.xticks(range(2005, 2025, 1))
plt.show()

# %%
grouped_rubi = varieties_grouped[varieties_grouped['variety'] == 'RUBIRED']


plt.figure(figsize=(10,6))
sns.lineplot(data=grouped_rubi, x='year', y='bearing_acre', marker='o')

plt.title('Rubired, Bearing Acreage per Year (2005–2024)')
plt.xlabel('Year')
plt.ylabel('Total Bearing Acres')

plt.tight_layout()
plt.xticks(range(2005, 2025, 1))
plt.show()

# %%
grouped_petite = varieties_grouped[varieties_grouped['variety'] == 'PETITE SIRAH']


plt.figure(figsize=(10,6))
sns.lineplot(data=grouped_petite, x='year', y='bearing_acre', marker='o')

plt.title('Petite Sirah, Bearing Acreage per Year (2005–2024)')
plt.xlabel('Year')
plt.ylabel('Total Bearing Acres')

plt.tight_layout()
plt.xticks(range(2005, 2025, 1))
plt.show()

# %%
##GOOGLE TRENDS
# 1. Per year, how does each variety scale on Google searches?

# %%
# 2. Are increases in Top Variety acreage associated with increases in Top Variety online actvity?

# %%
#https://pypi.org/project/pytrends/
from pytrends.request import TrendReq

# connect to google
pytrends = TrendReq(hl='en-US', tz=360)

# %%
kw_cab = ['cabernet sauvignon']
pytrends.build_payload(kw_cab, cat=0, timeframe='2005-01-01 2024-01-01', geo='US')

cab_data = pytrends.interest_over_time()
# data is chaotic, as it is daily data- smooth broad time series data with moving averages https://www.investopedia.com/terms/d/data-smoothing.asp
cab_data['moving_avg'] = cab_data['cabernet sauvignon'].rolling(window=12).mean() # 12 because the data is monthly
# rolling averages how-to - https://www.youtube.com/watch?v=FYji-5S8D2s
cab_data['moving_avg'].plot()
plt.title("'cabernet sauvignon', Google Trends (2005-2024)")
plt.show()
# plot documentation - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html

# moving averages in pandas - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rolling.html

# %%
kw_chenin = ['chenin blanc']
pytrends.build_payload(kw_chenin, cat=0, timeframe='2005-01-01 2024-01-01', geo='US')

chenin_data = pytrends.interest_over_time()
chenin_data['moving_avg'] = chenin_data['chenin blanc'].rolling(window=12).mean()
chenin_data['moving_avg'].plot()
plt.title("'chenin blanc', Google Trends (2005-2024)")
plt.show()

# %%
kw_gris = ['pinot gris']
pytrends.build_payload(kw_gris, cat=0, timeframe='2005-01-01 2024-01-01', geo='US')

gris_data = pytrends.interest_over_time()
gris_data['moving_avg'] = gris_data['pinot gris'].rolling(window=12).mean()
gris_data['moving_avg'].plot()
plt.title("'pinot gris', Google Trends (2005-2024)")
plt.show()

# %%
kw_grigio = ['pinot grigio']
pytrends.build_payload(kw_grigio, cat=0, timeframe='2005-01-01 2024-01-01', geo='US')

grigio_data = pytrends.interest_over_time()
grigio_data['moving_avg'] = grigio_data['pinot grigio'].rolling(window=12).mean()
grigio_data['moving_avg'].plot()
plt.title("'pinot grigio', Google Trends (2005-2024)")
plt.show()

# %%
kw_merlot = ['merlot']
pytrends.build_payload(kw_merlot, cat=0, timeframe='2005-01-01 2024-01-01', geo='US')

merlot_data = pytrends.interest_over_time()
merlot_data['moving_avg'] = merlot_data['merlot'].rolling(window=12).mean()
merlot_data['moving_avg'].plot()
plt.title("'merlot', Google Trends (2005-2024)")
plt.show()

# %%
kw_noir = ['pinot noir']
pytrends.build_payload(kw_noir, cat=0, timeframe='2005-01-01 2024-01-01', geo='US')

noir_data = pytrends.interest_over_time()
noir_data['moving_avg'] = noir_data['pinot noir'].rolling(window=12).mean()
noir_data['moving_avg'].plot()
plt.title("'pinot noir', Google Trends (2005-2024)")
plt.show()

# %%
kw_zin = ['zinfandel wine', 'zinfandel']
pytrends.build_payload(kw_zin, cat=0, timeframe='2005-01-01 2024-01-01', geo='US')

zin_data = pytrends.interest_over_time()
zin_data['moving_avg'] = zin_data['zinfandel wine'].rolling(window=12).mean()
zin_data['moving_avg'].plot()
plt.title("'zinfandel wine', Google Trends (2005-2024)")
plt.show()

# %%
kw_syrah = ['syrah wine', 'syrah']
pytrends.build_payload(kw_syrah, cat=0, timeframe='2005-01-01 2024-01-01', geo='US')

syrah_data = pytrends.interest_over_time()
syrah_data['moving_avg'] = syrah_data['syrah wine'].rolling(window=12).mean()
syrah_data['moving_avg'].plot()
plt.title("'syrah wine', Google Trends (2005-2024)")
plt.show()

# %%
kw_french = ['colombard'] # colombard wine is apparently not searched for
pytrends.build_payload(kw_french, cat=0, timeframe='2005-01-01 2024-01-01', geo='US')

french_data = pytrends.interest_over_time()
french_data['moving_avg'] = french_data['colombard'].rolling(window=12).mean()
french_data['moving_avg'].plot()
plt.title("'colombard', Google Trends (2005-2024)")
plt.show()

# %%
kw_petite = ['petite sirah wine', 'petite sirah']
pytrends.build_payload(kw_petite, cat=0, timeframe='2005-01-01 2024-01-01', geo='US')

petite_data = pytrends.interest_over_time()
petite_data['moving_avg'] = petite_data['petite sirah wine'].rolling(window=12).mean()
petite_data['moving_avg'].plot()
plt.title("'petite sirah wine', Google Trends (2005-2024)")
plt.show()

# %%
kw_rubi = ['rubired']
pytrends.build_payload(kw_rubi, cat=0, timeframe='2005-01-01 2024-01-01', geo='US')

rubi_data = pytrends.interest_over_time()
rubi_data['moving_avg'] = rubi_data['rubired'].rolling(window=12).mean()
rubi_data['moving_avg'].plot()
plt.title("'rubired', Google Trends (2005-2024)")
plt.show()

# %%
kw_chard = ['chardonnay wine']
pytrends.build_payload(kw_chard, cat=0, timeframe='2005-01-01 2024-01-01', geo='US')

chard_data = pytrends.interest_over_time()
chard_data['moving_avg'] = chard_data['chardonnay wine'].rolling(window=12).mean()
chard_data['moving_avg'].plot()
plt.title("'chardonnay wine', Google Trends (2005-2024)")
plt.show()

# %%
kw_sauv = ['sauvignon blanc']
pytrends.build_payload(kw_sauv, cat=0, timeframe='2005-01-01 2024-01-01', geo='US')

sauv_data = pytrends.interest_over_time()
sauv_data['moving_avg'] = sauv_data['sauvignon blanc'].rolling(window=12).mean()
sauv_data['moving_avg'].plot()
plt.title("'sauvignon blanc', Google Trends (2005-2024)")
plt.show()

# %%
top_varieties_list
# Out:
# ['CHENIN BLANC',
#  'PINOT GRIS',
#  'MERLOT',
#  'PINOT NOIR',
#  'ZINFANDEL',
#  'SYRAH',
#  'FRENCH COLOMBARD',
#  'PETITE SIRAH',
#  'RUBIRED',
#  'CABERNET SAUVIGNON',
#  'CHARDONNAY',
#  'SAUVIGNON BLANC']

# %%
##CLIMATE DATA
# https://www.fire.ca.gov/our-impact/statistics

# 1. Per year, what is the average temp (or proxy for climate) in California?

# %%
# 2. Per county, what is the average temp (or air quality if using wildfires), per year?

# %%
# 3. Is acreage dropping where temps are rising? (or use wildfire data/water use/land use as a proxy instead)

# %%
##CRUSH REPORT
# 1. Per year, what's the average (or median, if outliers) price per pound for Top Varieties?

# %%
# 2. Per Top Variety, whats the average price per pound, per year?

# %%
# 3. Are prices rising where acreage is rising?
# Is there a positive relationship between price per ton and bearing acreage for a grape variety (or in a region)
# — meaning, are growers responding to rising prices by planting more grapes?

# How has price per year for varieties in the Top 12 changed over time?

# %%
# Further data: Estimated total california wine acreage maybe + Total acreage (all varieties)
# More research on Chardonnay decrease in acreage and increase in Sauvingon Blanc + Pinot Gris
    # Market oversaturation? Chardonnay is possibly overplanted? Checking the crush report to compare price per ton
        # (less money to be made + less demand = reduced desire to grow chard); see if pinot gris/sauv blanc price per pound is up
        # if price is failing with acreage, could be a correlation, esp if sauv blanc and pinot gros rises are rising (filling the white wine market)
            # is falling acreage a response to falling prices, or is price staying stable because of falling supply?
    # Climate resistance? Is it possible that Sauvingon Blanc and Pinot Gris are more resilient to climate?
        # Early riping means missing any potentional fires, water efficency, heat tolerance. Is production risk a factor? Wildfire data could work here.
        # This would correlate best with the other top grapes also being these things.
    # Climate may not fully explain why acreage is down PERIOD (regional analysis would confirm or deny maybe)
        # Would have to consider demographic shifts and changes to viable land/water supply to know for sure
